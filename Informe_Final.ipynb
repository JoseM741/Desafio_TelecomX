# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseM741/Desafio_TelecomX/blob/main/Informe_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Informe TelecomX

# %% [markdown]
# ## Analisis descriptivo General
#
# -Evasión corresponde al 25,7%, el 74,3% no Evade

# %% [markdown]
# ![Proporcion evsasion.png](data:image/png;base64,...)

# %% [markdown]
# ![Evasion clientes.png](data:image/png;base64,...)

# %% [markdown]
# ##Abandono según tipo de Contrato

# %% [markdown]
# ![Abandono segun contrato.png](data:image/png;base64,...)

# %% [markdown]
# Clientes con contratos más largos tienen mayor permanencia, vs los contratos de tipo normal (que son mas cortos)

# %% [markdown]
# ##Evasión según tipo de Contrato

# %% [markdown]
# ![Evasión tipo Contrato.png](data:image/png;base64,...)

# %% [markdown]
# De acuerdo al análisis realizado la mayor evasión se produce en los Contratos de menor duración de tipo Mensual

# %% [markdown]
# ##Tipos de Categorías de evasión para Contrato Mensual

# %% [markdown]
# ![Top Categorias evasión contrato mensual.png](data:image/png;base64,...)

# %% [markdown]
# ##Principales conclusiones del análisis de evasión mensual:
#
# 1.- Forma de pago es determinante, por ejemplo, forma_pago Electronic check con una evasión sobre el 50%, claramente este método de pago se asocia fuertemente a abandono, esto suele pasar porque:
#
# Los pagos electrónicos inmediatos permiten cortar el servicio sin compromisos, ó podrían tener menor percepción de valor o menor fidelización.
#
#
# 📌 Acción sugerida: Ofrecer descuentos o beneficios si migran a débito automático o tarjeta.
#
#
#
# ---
#
#
# 2.- Servicios adicionales incrementan la evasión Categorías como servicio_peliculas, ó servicio_tv,  suelen estar asociadas a mayores tasas de abandono. Posible explicación: Estos servicios aumentan el gasto mensual.
#
# Si el cliente percibe que no los usa lo suficiente o son caros → cancela todo.
#
# 📌 Acción sugerida: Revisar precios o bundles de servicios y campañas para retener a quienes tienen estos servicios activos.
#
#
#
# ---
#
#
#
#
# 3.- Facturas electrónicas y soporte técnico, puede indicar que clientes más digitalizados son también más críticos y rápidos para cambiar de proveedor, como también puede indicar que clientes que solicitaron soporte técnico terminan abandonando más.
#
# 📌 Acción sugerida: Mejorar experiencia digital y servicio técnico.
#
#
#
#
# ---
#
#
#
# 4.- Clientes con dependientes o sin pareja Si tiene_dependentes = 0 o tiene_pareja = 0 tienen mayor evasión:
#
# Clientes sin responsabilidades familiares podrían tener mayor flexibilidad para cambiar de proveedor.
#
# 📌 Acción sugerida: Ofrecer beneficios familiares o contratos compartidos.
#
#
#
#
# ---
#
#
#
# 5.- Servicios de internet Si servicio_internet = Fiber optic con alta evasión:
#
# Podría indicar problemas de precio o servicio en ese segmento.
#
# 📌 Acción sugerida: Analizar reclamos o precios en ese plan.
#
#
#
# ---
#
#
#
# En resumen:
#
# -Forma de pago y servicios extra son los factores más vinculados a la evasión mensual.
#
# -Clientes más digitales o con menor compromiso familiar también son propensos a cambiarse.
